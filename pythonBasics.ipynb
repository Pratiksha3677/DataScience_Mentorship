# %% [markdown]
# <a href="https://colab.research.google.com/github/Pratiksha3677/DataScience_Mentorship/blob/main/pythonBasics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hi Pratiksha')
# Out:
# Hi Pratiksha

# %%
x = 20
print( X )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-347263124.py in <cell line: 0>()
#       1 x = 20
# ----> 2 print( X )
#
# NameError: name 'X' is not defined

# %%
x = 2
y = 5
print(x+y)
# Out:
# 7

# %%
print( x )
# Out:
# 2

# %%
print("Hello Pratiksha")
# Out:
# Hello Pratiksha
